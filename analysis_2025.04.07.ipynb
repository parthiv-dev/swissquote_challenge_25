# %%
from datetime import datetime
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# tickers = yf.Tickers('SYM GXO AUTO.OL KARN.SW ZBRA KGX.DE ABBN.SW CGNX 6383.T MANH')
# tickers = yf.Tickers('GF.SW AWK ECL VLTO BMI XYL') # Tickers of Giacomo
# tickers = yf.Tickers('GF AWK ECL VLTO BMI XYL NEE IBE.MC FSLR ENPH VWS.CO SGRE.MC BEP ORSTED.CO BKW.SW ENR')
# tickers = yf.Tickers('ECL BMI VLTO XYL GF.SW WM GFL CLH VEOEY CWST SRCL CWY.AX TMRAY SYM GXO AUTO.OL ZBRA KGX.DE CGNX DAIUF MANH BKW.SW ENLAY NEE IBDRY DNNGY FSLR ENR.DE')
tickers = yf.Tickers('ECL BMI VLTO XYL GF.SW WM GFL CLH VIE.PA CWST CWY.AX TOM.OL SYM GXO AUTO.OL ZBRA KGX.DE CGNX MANH BKW.SW ENEL.MI NEE IBE.MC ORSTED.CO FSLR ENR.DE')

# %%
# df = tickers.download(period="1y")
df = tickers.download(start="2020-01-01", end="2025-01-01", interval="1d")
# Out:
# [*********************100%***********************]  26 of 26 completed

# %%
# Save the dataframe to CSV with the timestamp included
filename = f'data/ticker_download_{datetime.now().strftime("%Y.%m.%d_%H.%M")}.csv'
df.to_csv(filename, index=False)

# %%
# Initialize list to store company data
company_data = []

# Loop through each ticker
for ticker in tickers.symbols:

    # Print ticker for debugging
    print(f"Processing {ticker}...")

    # Get ticker object
    t = yf.Ticker(ticker)
    
    # Get info and historical data
    try:
        info = t.info
        # print(f"Sucessful fetching info for {ticker}: {info}")
    except Exception as e:
        print(f"Error fetching info for {ticker}: {e}")
        continue
    
    # hist = t.history(period="2y")
    hist = t.history(start = '2020-01-01', end = '2024-12-31')

    # Calculate required metrics
    company_name = info.get('shortName', 'N/A')
    description = info.get('longBusinessSummary', 'N/A')
    market_cap = round(info.get('marketCap', 0) / 1e9, 2) if info.get('marketCap') else 'N/A'  # In billion USD
    volume = round(hist['Volume'].mean() / 1e6, 2) if 'Volume' in hist else 'N/A'  # In million shares
    start_of_period = hist.loc[hist.index[0], 'Close'] if not hist.empty else 'N/A'
    end_of_period = hist.loc[hist.index[-1], 'Close'] if not hist.empty else 'N/A'
    
    # Calculate deltas
    delta_this_year = ((end_of_period - start_of_period) / start_of_period * 100) if start_of_period != 'N/A' else 'N/A'
    delta_last_year = 'N/A'  # Placeholder if data not fetched for previous year
    delta_total = delta_this_year  # Adjust as needed when more data is available

    # Append to company data
    company_data.append([
        ticker,
        company_name,
        description,
        f"${market_cap}B" if market_cap != 'N/A' else 'N/A',
        f"{volume}M" if volume != 'N/A' else 'N/A',
        round(delta_this_year, 2) if delta_this_year != 'N/A' else 'N/A',
        delta_last_year,
        delta_total
    ])

# Create DataFrame
columns = ["Ticker", "Company Name", "Description", "Market Cap (USD)", "Avg Daily Volume (M)", "Delta This Year (%)", "Delta Last Year (%)", "Delta Total (%)"]
df_summary = pd.DataFrame(company_data, columns=columns)
# Out:
# Processing ECL...
# Processing BMI...
# Processing VLTO...
# Processing XYL...
# Processing GF.SW...
# Processing WM...
# Processing GFL...

# %%
df_summary
# Out:
#        Ticker                     Company Name  \
# 0         ECL                      Ecolab Inc.
# 1         BMI               Badger Meter, Inc.
# 2        VLTO                     Veralto Corp
# 3         XYL                       Xylem Inc.
# 4       GF.SW                  GEORG FISCHER N
# 5          WM           Waste Management, Inc.
# 6         GFL  GFL Environmental Inc. Subordin
# 7         CLH              Clean Harbors, Inc.
# 8      VIE.PA                  VEOLIA ENVIRON.
# 9        CWST      Casella Waste Systems, Inc.
# 10     CWY.AX              CLEANAWAY FPO [CWY]
# 11     TOM.OL                    TOMRA SYSTEMS
# 12        SYM                    Symbotic Inc.
# 13        GXO              GXO Logistics, Inc.
# 14    AUTO.OL          AUTOSTORE HOLDINGS LTD.
# 15       ZBRA   Zebra Technologies Corporation
# 16     KGX.DE  KION GROUP AG                 I
# 17       CGNX               Cognex Corporation
# 18       MANH       Manhattan Associates, Inc.
# 19     BKW.SW                            BKW N
# 20    ENEL.MI                             ENEL
# 21        NEE             NextEra Energy, Inc.
# 22     IBE.MC               ACCIONES IBERDROLA
# 23  ORSTED.CO                       ORSTED A/S
# 24       FSLR                First Solar, Inc.
# 25     ENR.DE  Siemens Energy AG             N
#
#                                           Description Market Cap (USD)  \
# 0   Ecolab Inc. provides water, hygiene, and infec...          $65.33B
# 1   Badger Meter, Inc. manufactures and markets fl...           $5.08B
# 2   Veralto Corporation provides water analytics, ...          $21.61B
# 3   Xylem Inc., together with its subsidiaries, en...          $25.23B
# 4                                                 N/A           $4.41B
# 5   Waste Management, Inc., through its subsidiari...          $88.74B
# 6   GFL Environmental Inc. provides non-hazardous ...          $16.16B
# 7   Clean Harbors, Inc. provides environmental and...          $10.04B
# 8   Veolia Environnement SA designs and provides w...          $21.88B
# 9   Casella Waste Systems, Inc., together with its...           $6.59B
# 10  Cleanaway Waste Management Limited provides wa...           $5.82B
# 11  Tomra Systems ASA provides sensor-based soluti...          $42.26B
# 12  Symbotic Inc., an automation technology compan...          $10.92B
# 13  GXO Logistics, Inc., together with its subsidi...           $4.08B
# 14  AutoStore Holdings Ltd., a robotic and softwar...          $24.26B
# 15  Zebra Technologies Corporation, together with ...          $11.43B
# 16  KION GROUP AG provides industrial trucks and s...            $4.0B
# 17  Cognex Corporation provides machine vision pro...           $4.15B
# 18  Manhattan Associates, Inc. develops, sells, de...           $8.89B
# 19  BKW AG, an international energy and infrastruc...           $7.78B
# 20  Enel SpA operates as an integrated operator in...          $73.06B
# 21  NextEra Energy, Inc., through its subsidiaries...         $133.93B
# 22  Iberdrola, S.A. engages in the generation, pro...          $89.67B
# 23  Ørsted A/S, together with its subsidiaries, ow...         $113.13B
# 24  First Solar, Inc., a solar technology company,...          $13.92B
# 25  Siemens Energy AG operates as an energy techno...          $38.37B
#
#    Avg Daily Volume (M)  Delta This Year (%) Delta Last Year (%)  \
# 0                 1.31M                30.10                 N/A
# 1                 0.16M               249.01                 N/A
# 2                 1.83M                31.62                 N/A
# 3                 1.22M                54.54                 N/A
# 4                  0.2M                54.79                 N/A
# 5                 1.74M                92.39                 N/A
# 6                  1.2M               166.70                 N/A
# 7                 0.34M               170.71                 N/A
# 8                 1.85M                39.23                 N/A
# 9                 0.27M               129.37                 N/A
# 10                5.52M                46.01                 N/A
# 11                 0.5M                 6.68                 N/A
# 12                0.83M               137.66                 N/A
# 13                0.94M               -20.84                 N/A
# 14                2.93M               -68.01                 N/A
# 15                0.38M                48.12                 N/A
# 16                0.28M               -46.21                 N/A
# 17                0.98M               -33.61                 N/A
# 18                0.39M               236.07                 N/A
# 19                0.06M               137.22                 N/A
# 20               25.77M                29.80                 N/A
# 21                9.33M                35.30                 N/A
# 22               13.61M                77.26                 N/A
# 23                0.56M               -49.28                 N/A
# 24                2.25M               211.09                 N/A
# 25                2.88M               128.81                 N/A
#
#     Delta Total (%)
# 0         30.100226
# 1        249.014147
# 2         31.620392
# 3         54.544403
# 4         54.790509
# 5         92.389210
# 6        166.702315
# 7        170.712788
# 8         39.234714
# 9        129.373369
# 10        46.014352
# 11         6.680979
# 12       137.658543
# 13       -20.844038
# 14       -68.014972
# 15        48.124560
# 16       -46.209112
# 17       -33.610271
# 18       236.068435
# 19       137.217976
# 20        29.798055
# 21        35.297411
# 22        77.263447
# 23       -49.278407
# 24       211.093644
# 25       128.810664

# %%
# Display the data
df
# Out:
# Price        Close                                                             \
# Ticker     AUTO.OL      BKW.SW         BMI       CGNX         CLH        CWST
# Date
# 2020-01-02     NaN         NaN   61.286888  53.598686   85.019997   45.959999
# 2020-01-03     NaN   63.317287   61.277294  52.992741   85.279999   46.830002
# 2020-01-06     NaN   63.673508   61.018250  52.311039   85.239998   47.689999
# 2020-01-07     NaN   64.564049   60.835960  52.150082   84.230003   47.840000
# 2020-01-08     NaN   65.454582   61.469170  52.585613   82.800003   47.400002
# ...            ...         ...         ...        ...         ...         ...
# 2024-12-24     NaN         NaN  219.640457  36.601562  230.940002  106.239998
# 2024-12-26     NaN         NaN  219.590530  36.850960  231.330002  107.550003
# 2024-12-27   11.36  151.699997  215.097885  35.953133  229.570007  106.160004
# 2024-12-30   11.11  150.199997  213.899857  35.584023  230.160004  105.419998
# 2024-12-31     NaN         NaN  211.773331  35.773567  230.139999  105.809998
#
# Price                                                  ...    Volume  \
# Ticker        CWY.AX         ECL   ENEL.MI     ENR.DE  ...      MANH
# Date                                                   ...
# 2020-01-02  1.815361  179.795822  5.145772        NaN  ...  284400.0
# 2020-01-03  1.815361  178.935760  5.145059        NaN  ...  331200.0
# 2020-01-06  1.833424  177.414078  5.155762        NaN  ...  402900.0
# 2020-01-07  1.833424  177.187225  5.158616        NaN  ...  243100.0
# 2020-01-08  1.842456  177.253326  5.187156        NaN  ...  306700.0
# ...              ...         ...       ...        ...  ...       ...
# 2024-12-24  2.650687  240.118759       NaN        NaN  ...  130300.0
# 2024-12-26       NaN  238.742310       NaN        NaN  ...  276200.0
# 2024-12-27  2.660578  237.146439  6.641284  50.080002  ...  482700.0
# 2024-12-30  2.650687  233.914810  6.679112  50.080002  ...  199600.0
# 2024-12-31  2.621016  233.715332       NaN        NaN  ...  330900.0
#
# Price                                                                       \
# Ticker            NEE  ORSTED.CO        SYM    TOM.OL     VIE.PA      VLTO
# Date
# 2020-01-02  7884800.0   340491.0        NaN  434136.0  1129682.0       NaN
# 2020-01-03  7097200.0   294193.0        NaN  375230.0  1278025.0       NaN
# 2020-01-06  5518800.0   385408.0        NaN  443118.0  1142428.0       NaN
# 2020-01-07  6653200.0   429359.0        NaN  635558.0  1256686.0       NaN
# 2020-01-08  5936000.0  1422811.0        NaN  675858.0  1900237.0       NaN
# ...               ...        ...        ...       ...        ...       ...
# 2024-12-24  3001800.0        NaN   836000.0       NaN   483988.0  277500.0
# 2024-12-26  4503800.0        NaN   805000.0       NaN        NaN  580100.0
# 2024-12-27  5458100.0   371815.0  1047100.0  169342.0   988218.0  608800.0
# 2024-12-30  8399000.0   416919.0  1165200.0  153435.0   784850.0  528600.0
# 2024-12-31  6216500.0        NaN   920100.0       NaN   764730.0  644000.0
#
# Price
# Ticker             WM        XYL      ZBRA
# Date
# 2020-01-02  2071700.0   869500.0  387800.0
# 2020-01-03  1424900.0   795100.0  305300.0
# 2020-01-06  1840700.0   817300.0  322600.0
# 2020-01-07  2325500.0   662200.0  236300.0
# 2020-01-08  1824600.0  1083200.0  689600.0
# ...               ...        ...       ...
# 2024-12-24   711500.0   379300.0   88700.0
# 2024-12-26   736700.0   575700.0  140100.0
# 2024-12-27   878700.0   552400.0  287200.0
# 2024-12-30  1209700.0   586800.0  211300.0
# 2024-12-31  1549000.0   641600.0  327900.0
#
# [1293 rows x 182 columns]

# %%
# Save the dataframe to CSV with the timestamp included
filename = f'data/data_close_{datetime.now().strftime("%Y.%m.%d_%H.%M")}.csv'
df['Close'].to_csv(filename, index=False)
df['Close']
# Out:
# Ticker      AUTO.OL      BKW.SW         BMI       CGNX         CLH  \
# Date
# 2020-01-02      NaN         NaN   61.286888  53.598686   85.019997
# 2020-01-03      NaN   63.317287   61.277294  52.992741   85.279999
# 2020-01-06      NaN   63.673508   61.018250  52.311039   85.239998
# 2020-01-07      NaN   64.564049   60.835960  52.150082   84.230003
# 2020-01-08      NaN   65.454582   61.469170  52.585613   82.800003
# ...             ...         ...         ...        ...         ...
# 2024-12-24      NaN         NaN  219.640457  36.601562  230.940002
# 2024-12-26      NaN         NaN  219.590530  36.850960  231.330002
# 2024-12-27    11.36  151.699997  215.097885  35.953133  229.570007
# 2024-12-30    11.11  150.199997  213.899857  35.584023  230.160004
# 2024-12-31      NaN         NaN  211.773331  35.773567  230.139999
#
# Ticker            CWST    CWY.AX         ECL   ENEL.MI     ENR.DE  ...  \
# Date                                                               ...
# 2020-01-02   45.959999  1.815361  179.795822  5.145772        NaN  ...
# 2020-01-03   46.830002  1.815361  178.935760  5.145059        NaN  ...
# 2020-01-06   47.689999  1.833424  177.414078  5.155762        NaN  ...
# 2020-01-07   47.840000  1.833424  177.187225  5.158616        NaN  ...
# 2020-01-08   47.400002  1.842456  177.253326  5.187156        NaN  ...
# ...                ...       ...         ...       ...        ...  ...
# 2024-12-24  106.239998  2.650687  240.118759       NaN        NaN  ...
# 2024-12-26  107.550003       NaN  238.742310       NaN        NaN  ...
# 2024-12-27  106.160004  2.660578  237.146439  6.641284  50.080002  ...
# 2024-12-30  105.419998  2.650687  233.914810  6.679112  50.080002  ...
# 2024-12-31  105.809998  2.621016  233.715332       NaN        NaN  ...
#
# Ticker            MANH        NEE   ORSTED.CO        SYM      TOM.OL  \
# Date
# 2020-01-02   80.680000  52.605259  639.175598        NaN  137.419083
# 2020-01-03   80.440002  52.980045  635.796692        NaN  135.795639
# 2020-01-06   81.400002  53.244579  629.038879        NaN  133.694733
# 2020-01-07   81.400002  53.198284  621.342407        NaN  130.829834
# 2020-01-08   82.500000  53.174038  605.386536        NaN  133.026260
# ...                ...        ...         ...        ...         ...
# 2024-12-24  282.269989  72.314156         NaN  24.549999         NaN
# 2024-12-26  279.299988  71.778564         NaN  24.820000         NaN
# 2024-12-27  275.190002  71.520691  330.299988  24.080000  149.199997
# 2024-12-30  271.140015  71.173553  324.200012  24.360001  146.600006
# 2024-12-31  270.239990  71.104126         NaN  23.709999         NaN
#
# Ticker         VIE.PA        VLTO          WM         XYL        ZBRA
# Date
# 2020-01-02  19.276802         NaN  104.747231   75.007912  259.140015
# 2020-01-03  19.373466         NaN  105.765175   75.449402  256.049988
# 2020-01-06  19.260691         NaN  106.315407   74.960938  258.010010
# 2020-01-07  19.091524         NaN  106.388771   74.679123  256.470001
# 2020-01-08  18.994860         NaN  106.452972   74.932770  247.639999
# ...               ...         ...         ...         ...         ...
# 2024-12-24  26.799999  103.260002  204.620865  117.784721  395.440002
# 2024-12-26        NaN  103.639160  204.262192  118.103729  396.850006
# 2024-12-27  26.940001  102.890823  203.265900  117.166634  389.070007
# 2024-12-30  26.840000  101.783295  201.522354  115.920494  383.850006
# 2024-12-31  27.110001  101.733345  201.044128  115.661301  386.220001
#
# [1293 rows x 26 columns]

# %%
# Plot closing prices
plt.plot(df['Close'])
# plt.legend(df.columns)
plt.title('Closing Prices')
plt.ylabel('Price')
plt.show()

# %%
# Number of rows in dataframe without missing values
print(f"Number of rows in dataframe without missing values: {df.dropna().shape[0]}")
print(f"Number of rows total: {df.shape[0]}")

# Drop columns with more than 50% NaN values
df = df.dropna(thresh=len(df) * 0.5, axis=1)

# Number of rows in dataframe without missing values
print(f"Number of rows in dataframe without missing values after dropping bad columns: {df.dropna().shape[0]}")
print(f"Number of rows total after dropping bad columns: {df.shape[0]}")

# Plot closing prices
plt.plot(df['Close'])
# plt.legend(df.columns)
plt.title('Closing Prices')
plt.ylabel('Price')
plt.show()
# Out:
# Number of rows in dataframe without missing values: 295
# Number of rows total: 1293
# Number of rows in dataframe without missing values after dropping bad columns: 754
# Number of rows total after dropping bad columns: 1293

# %%
# Number of rows in dataframe without missing values
print(f"Number of rows in dataframe without missing values: {df.dropna().shape[0]}")
print(f"Number of rows total: {df.shape[0]}")

df = df.dropna()

# Plot closing prices
plt.plot(df['Close'])
# plt.legend(df.columns)
plt.title('Closing Prices')
plt.ylabel('Price')
plt.show()
# Out:
# Number of rows in dataframe without missing values: 754
# Number of rows total: 1293

# %%
df_normalized_closed = df['Close'] - df['Close'].iloc[0]
df_normalized_closed
# Out:
# Ticker        AUTO.OL     BKW.SW         BMI       CGNX         CLH  \
# Date
# 2021-10-21   0.000000   0.000000    0.000000   0.000000    0.000000
# 2021-10-22   2.044998   1.125381   -0.048729  -0.909744    0.839996
# 2021-10-25   1.505001   0.562691   -0.672523   0.273911    0.339996
# 2021-10-26   2.264999   0.937820   -1.179329   0.948875   -0.389999
# 2021-10-27   1.105000   0.375137   -2.982437  -0.753220   -2.310005
# ...               ...        ...         ...        ...         ...
# 2024-12-19 -23.885000  37.175499  116.222565 -47.997112  119.660004
# 2024-12-20 -23.735001  37.675499  115.483765 -48.296391  116.589996
# 2024-12-23 -23.575001  40.675499  114.635147 -47.917305  114.669998
# 2024-12-27 -23.375001  41.975502  113.217468 -48.027039  115.630005
# 2024-12-30 -23.625001  40.475502  112.019440 -48.396149  116.220001
#
# Ticker           CWST    CWY.AX        ECL   ENEL.MI     ENR.DE  ...  \
# Date                                                             ...
# 2021-10-21   0.000000  0.000000   0.000000  0.000000   0.000000  ...
# 2021-10-22   1.730003 -0.009361  -0.816330 -0.036532  -0.189026  ...
# 2021-10-25   1.400002  0.009360  -0.710678 -0.088947  -0.397947  ...
# 2021-10-26   1.520004  0.028082   7.664047 -0.022237   0.567074  ...
# 2021-10-27   1.020004 -0.074886  -1.152435  0.034150   0.666561  ...
# ...               ...       ...        ...       ...        ...  ...
# 2024-12-19  23.510002 -0.026999  21.424927  0.900081  26.023684  ...
# 2024-12-20  24.090004 -0.017108  24.177795  0.904931  26.723684  ...
# 2024-12-23  22.930000  0.012563  24.975739  0.898141  27.143682  ...
# 2024-12-27  24.280006 -0.007218  23.649170  0.944699  26.103685  ...
# 2024-12-30  23.540001 -0.017108  20.417542  0.982527  26.103685  ...
#
# Ticker         KGX.DE        MANH       NEE   ORSTED.CO        SYM     TOM.OL  \
# Date
# 2021-10-21   0.000000    0.000000  0.000000    0.000000   0.000000   0.000000
# 2021-10-22   0.378891   -0.360001  0.557335   -6.360840   0.000000  13.903793
# 2021-10-25  -0.322060    1.080002  0.438576  -13.492737   0.000000  13.419342
# 2021-10-26   4.811867    0.899994  1.516716  -14.649170   0.080000  21.461288
# 2021-10-27   2.690094   10.529999  1.096436   -3.469543   0.040000  18.070084
# ...               ...         ...       ...         ...        ...        ...
# 2024-12-19 -52.581440  113.540009 -7.375320 -549.359467  13.140001 -94.364548
# 2024-12-20 -52.401440  111.260010 -5.490845 -548.859467  14.090000 -85.564545
# 2024-12-23 -52.121441  109.820007 -4.677544 -546.759460  15.630001 -88.264542
# 2024-12-27 -51.651440  106.190002 -5.054436 -551.159485  14.180000 -87.164551
# 2024-12-30 -51.651440  102.140015 -5.401573 -557.259460  14.460001 -89.764542
#
# Ticker        VIE.PA         WM       XYL        ZBRA
# Date
# 2021-10-21  0.000000   0.000000  0.000000    0.000000
# 2021-10-22  0.449440   2.403793  0.661537   -5.690002
# 2021-10-25  0.220314  -0.690903  0.939590   -1.149963
# 2021-10-26  0.352499  -2.460602 -0.258888   -8.200012
# 2021-10-27  0.193874  -6.369141 -0.067139  -15.769958
# ...              ...        ...       ...         ...
# 2024-12-19  2.172583  51.570572 -6.721344 -148.239990
# 2024-12-20  2.142582  51.869461 -6.013542 -140.569977
# 2024-12-23  2.072582  49.846970 -5.644684 -142.959991
# 2024-12-27  2.282583  50.066162 -5.624748 -144.539978
# 2024-12-30  2.182583  48.322617 -6.870888 -149.759979
#
# [754 rows x 25 columns]

# %%
# Plot normalized closing prices
plt.plot(df_normalized_closed)
# plt.legend(df.columns)
plt.title('Normalized Closing Prices')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# This plot shows why we cannot weight stocks equally. Some stocks are more volatile than others.

# %%
# Add a new column to the DataFrame with daily differences
df_diff = df['Close'].diff()
# Drop the first row (NaN)
df_diff = df_diff.dropna()
df_diff
# Out:
# Ticker       AUTO.OL    BKW.SW       BMI      CGNX       CLH      CWST  \
# Date
# 2021-10-22  2.044998  1.125381 -0.048729 -0.909744  0.839996  1.730003
# 2021-10-25 -0.539997 -0.562691 -0.623795  1.183655 -0.500000 -0.330002
# 2021-10-26  0.759998  0.375130 -0.506805  0.674965 -0.729996  0.120003
# 2021-10-27 -1.160000 -0.562683 -1.803108 -1.702095 -1.920006 -0.500000
# 2021-10-28 -1.090000  1.312943  0.575043  1.672752  0.740005  0.239998
# ...              ...       ...       ...       ...       ...       ...
# 2024-12-19 -0.639999 -0.500000 -0.988373  0.458893 -1.449997 -0.559998
# 2024-12-20  0.150000  0.500000 -0.738800 -0.299278 -3.070007  0.580002
# 2024-12-23  0.160000  3.000000 -0.848618  0.379086 -1.919998 -1.160004
# 2024-12-27  0.200000  1.300003 -1.417679 -0.109734  0.960007  1.350006
# 2024-12-30 -0.250000 -1.500000 -1.198029 -0.369110  0.589996 -0.740005
#
# Ticker        CWY.AX       ECL   ENEL.MI    ENR.DE  ...    KGX.DE      MANH  \
# Date                                                ...
# 2021-10-22 -0.009361 -0.816330 -0.036532 -0.189026  ...  0.378891 -0.360001
# 2021-10-25  0.018721  0.105652 -0.052415 -0.208921  ... -0.700951  1.440002
# 2021-10-26  0.018722  8.374725  0.066710  0.965021  ...  5.133926 -0.180008
# 2021-10-27 -0.102968 -8.816483  0.056386  0.099487  ... -2.121773  9.630005
# 2021-10-28 -0.056164 -0.096069  0.042885  0.457638  ...  2.254387  1.589996
# ...              ...       ...       ...       ...  ...       ...       ...
# 2024-12-19 -0.059344 -2.124512 -0.111545 -1.220001  ... -0.910000  0.910004
# 2024-12-20  0.009891  2.752869  0.004850  0.700001  ...  0.180000 -2.279999
# 2024-12-23  0.029672  0.797943 -0.006790  0.419998  ...  0.279999 -1.440002
# 2024-12-27 -0.019781 -1.326569  0.046558 -1.039997  ...  0.470001 -3.630005
# 2024-12-30 -0.009891 -3.231628  0.037828  0.000000  ...  0.000000 -4.049988
#
# Ticker           NEE  ORSTED.CO       SYM     TOM.OL    VIE.PA        WM  \
# Date
# 2021-10-22  0.557335  -6.360840  0.000000  13.903793  0.449440  2.403793
# 2021-10-25 -0.118759  -7.131897  0.000000  -0.484451 -0.229126 -3.094696
# 2021-10-26  1.078140  -1.156433  0.080000   8.041946  0.132185 -1.769699
# 2021-10-27 -0.420280  11.179626 -0.040000  -3.391205 -0.158625 -3.908539
# 2021-10-28  1.288261  13.492737  0.010000  11.529999  0.493504  2.223999
# ...              ...        ...       ...        ...       ...       ...
# 2024-12-19 -0.743874  -6.500000 -0.929998  -6.600006 -0.190001  0.099640
# 2024-12-20  1.884476   0.500000  0.949999   8.800003 -0.030001  0.298889
# 2024-12-23  0.813301   2.100006  1.540001  -2.699997 -0.070000 -2.022491
# 2024-12-27 -0.376892  -4.400024 -1.450001   1.099991  0.210001  0.219193
# 2024-12-30 -0.347137  -6.099976  0.280001  -2.599991 -0.100000 -1.743546
#
# Ticker           XYL       ZBRA
# Date
# 2021-10-22  0.661537  -5.690002
# 2021-10-25  0.278053   4.540039
# 2021-10-26 -1.198479  -7.050049
# 2021-10-27  0.191750  -7.569946
# 2021-10-28  3.077698  14.219971
# ...              ...        ...
# 2024-12-19 -0.488480   1.899994
# 2024-12-20  0.707802   7.670013
# 2024-12-23  0.368858  -2.390015
# 2024-12-27  0.019936  -1.579987
# 2024-12-30 -1.246140  -5.220001
#
# [753 rows x 25 columns]

# %%
# Add a new column to the DataFrame with daily difference relative to the previous day
df_diff_relative = df['Close'].pct_change()
# Drop the first row (NaN)
df_diff_relative = df_diff_relative.dropna()
df_diff_relative
# Out:
# Ticker       AUTO.OL    BKW.SW       BMI      CGNX       CLH      CWST  \
# Date
# 2021-10-22  0.058874  0.010256 -0.000478 -0.010833  0.007372  0.021129
# 2021-10-25 -0.014682 -0.005076 -0.006126  0.014249 -0.004356 -0.003947
# 2021-10-26  0.020971  0.003401 -0.005008  0.008011 -0.006388  0.001441
# 2021-10-27 -0.031351 -0.005085 -0.017906 -0.020041 -0.016909 -0.005995
# 2021-10-28 -0.030413  0.011925  0.005815  0.020099  0.006629  0.002895
# ...              ...       ...       ...       ...       ...       ...
# 2024-12-19 -0.055701 -0.003392 -0.004511  0.012918 -0.006169 -0.005285
# 2024-12-20  0.013825  0.003404 -0.003387 -0.008317 -0.013142  0.005503
# 2024-12-23  0.014545  0.020353 -0.003904  0.010623 -0.008329 -0.010947
# 2024-12-27  0.017921  0.008644 -0.006548 -0.003043  0.004199  0.012881
# 2024-12-30 -0.022007 -0.009888 -0.005570 -0.010266  0.002570 -0.006971
#
# Ticker        CWY.AX       ECL   ENEL.MI    ENR.DE  ...    KGX.DE      MANH  \
# Date                                                ...
# 2021-10-22 -0.003509 -0.003824 -0.006413 -0.007884  ...  0.004532 -0.002130
# 2021-10-25  0.007042  0.000497 -0.009260 -0.008783  ... -0.008347  0.008539
# 2021-10-26  0.006993  0.039357  0.011896  0.040928  ...  0.061647 -0.001058
# 2021-10-27 -0.038194 -0.039864  0.009937  0.004054  ... -0.023998  0.056680
# 2021-10-28 -0.021661 -0.000452  0.007483  0.018571  ...  0.026125  0.008856
# ...              ...       ...       ...       ...  ...       ...       ...
# 2024-12-19 -0.021978 -0.008962 -0.016628 -0.023819  ... -0.028500  0.003231
# 2024-12-20  0.003745  0.011718  0.000735  0.014000  ...  0.005803 -0.008070
# 2024-12-23  0.011194  0.003357 -0.001029  0.008284  ...  0.008974 -0.005138
# 2024-12-27 -0.007380 -0.005563  0.007060 -0.020344  ...  0.014930 -0.013019
# 2024-12-30 -0.003718 -0.013627  0.005696  0.000000  ...  0.000000 -0.014717
#
# Ticker           NEE  ORSTED.CO       SYM    TOM.OL    VIE.PA        WM  \
# Date
# 2021-10-22  0.007278  -0.007216  0.000000  0.058824  0.018227  0.015691
# 2021-10-25 -0.001540  -0.008150  0.000000 -0.001936 -0.009126 -0.019888
# 2021-10-26  0.013999  -0.001332  0.008081  0.032196  0.005313 -0.011604
# 2021-10-27 -0.005382   0.012897 -0.004008 -0.013153 -0.006342 -0.025929
# 2021-10-28  0.016586   0.015368  0.001006  0.045316  0.019858  0.015147
# ...              ...        ...       ...       ...       ...       ...
# 2024-12-19 -0.010635  -0.019197 -0.038798 -0.044415 -0.007032  0.000487
# 2024-12-20  0.027232   0.001506  0.041233  0.061972 -0.001118  0.001460
# 2024-12-23  0.011441   0.006314  0.064193 -0.017904 -0.002612 -0.009862
# 2024-12-27 -0.005242  -0.013146 -0.056796  0.007427  0.007856  0.001080
# 2024-12-30 -0.004854  -0.018468  0.011628 -0.017426 -0.003712 -0.008578
#
# Ticker           XYL      ZBRA
# Date
# 2021-10-22  0.005387 -0.010663
# 2021-10-25  0.002252  0.008600
# 2021-10-26 -0.009686 -0.013241
# 2021-10-27  0.001565 -0.014408
# 2021-10-28  0.025078  0.027460
# ...              ...       ...
# 2024-12-19 -0.004191  0.004955
# 2024-12-20  0.006098  0.019903
# 2024-12-23  0.003159 -0.006081
# 2024-12-27  0.000170 -0.004045
# 2024-12-30 -0.010636 -0.013417
#
# [753 rows x 25 columns]

# %%
# Add a new column 'Volatility' to DataFrame df_mini
# Calculate the volatility of each stock in the past year based on normalized closing prices
df_mini = pd.DataFrame()

df_mini['Volatility'] = df_diff_relative.std()

df_mini
# Out:
#            Volatility
# Ticker
# AUTO.OL      0.044048
# BKW.SW       0.014690
# BMI          0.019867
# CGNX         0.025201
# CLH          0.019559
# CWST         0.016296
# CWY.AX       0.015465
# ECL          0.016484
# ENEL.MI      0.014145
# ENR.DE       0.034732
# FSLR         0.034227
# GF.SW        0.019643
# GFL          0.020675
# GXO          0.027668
# IBE.MC       0.012306
# KGX.DE       0.030364
# MANH         0.022782
# NEE          0.018016
# ORSTED.CO    0.029403
# SYM          0.076144
# TOM.OL       0.030266
# VIE.PA       0.017198
# WM           0.012210
# XYL          0.017338
# ZBRA         0.025979

# %%
# Calculate final weighting based on volatility 
df_mini['Inverse Volatility'] = 1 / df_mini['Volatility']
sum_inverse_volatility = df_mini['Inverse Volatility'].sum()
df_mini['Volatility Weighting'] = df_mini['Inverse Volatility'] / sum_inverse_volatility
df_mini['Volatility Weighting (%)'] = (df_mini['Volatility Weighting'] * 100).round(2)
df_mini
# Out:
#            Volatility  Inverse Volatility  Volatility Weighting  \
# Ticker
# AUTO.OL      0.044048           22.702533              0.018720
# BKW.SW       0.014690           68.072875              0.056132
# BMI          0.019867           50.334452              0.041505
# CGNX         0.025201           39.680495              0.032720
# CLH          0.019559           51.127817              0.042160
# CWST         0.016296           61.366516              0.050602
# CWY.AX       0.015465           64.661257              0.053319
# ECL          0.016484           60.665723              0.050024
# ENEL.MI      0.014145           70.695152              0.058295
# ENR.DE       0.034732           28.791762              0.023741
# FSLR         0.034227           29.217118              0.024092
# GF.SW        0.019643           50.908365              0.041979
# GFL          0.020675           48.367450              0.039883
# GXO          0.027668           36.142409              0.029803
# IBE.MC       0.012306           81.257988              0.067005
# KGX.DE       0.030364           32.933297              0.027157
# MANH         0.022782           43.893404              0.036194
# NEE          0.018016           55.507279              0.045771
# ORSTED.CO    0.029403           34.009724              0.028044
# SYM          0.076144           13.133054              0.010829
# TOM.OL       0.030266           33.040011              0.027245
# VIE.PA       0.017198           58.147574              0.047948
# WM           0.012210           81.897361              0.067532
# XYL          0.017338           57.676135              0.047559
# ZBRA         0.025979           38.491937              0.031740
#
#            Volatility Weighting (%)
# Ticker
# AUTO.OL                        1.87
# BKW.SW                         5.61
# BMI                            4.15
# CGNX                           3.27
# CLH                            4.22
# CWST                           5.06
# CWY.AX                         5.33
# ECL                            5.00
# ENEL.MI                        5.83
# ENR.DE                         2.37
# FSLR                           2.41
# GF.SW                          4.20
# GFL                            3.99
# GXO                            2.98
# IBE.MC                         6.70
# KGX.DE                         2.72
# MANH                           3.62
# NEE                            4.58
# ORSTED.CO                      2.80
# SYM                            1.08
# TOM.OL                         2.72
# VIE.PA                         4.79
# WM                             6.75
# XYL                            4.76
# ZBRA                           3.17

# %%
# Print number of stocks:
print(f"Number of stocks: {len(df_mini)}")
# Out:
# Number of stocks: 25

# %%
# Print name of stock with lowest and highest volatility
print(f"Lowest weighting (%): {df_mini['Volatility Weighting (%)'].idxmin()} ({df_mini['Volatility Weighting (%)'].min()})")
print(f"Highest weighting (%): {df_mini['Volatility Weighting (%)'].idxmax()} ({df_mini['Volatility Weighting (%)'].max()})")
# Out:
# Lowest weighting (%): SYM (1.08)
# Highest weighting (%): WM (6.75)

# %%
# Plot closing price of CWY.AX and ENLAY
plt.plot(df['Close']['IBE.MC'], label='IBE.MC')
plt.plot(df['Close']['SYM'], label='SYM')
plt.legend()
plt.title('Closing Prices of IBE.MC and SYM')
plt.ylabel('Price')
plt.show()

# %%
# Calculate sum of final weighting to verify correctness
sum_final_weighting = df_mini['Volatility Weighting'].sum()
sum_final_weighting
# Out:
# np.float64(0.9999999999999999)
